# %% [markdown]
# ## Import the necessary modules.
# Specify the version of the config file (it will set the OA-version dependent names, e.g. plot tag, output directory name etc)

# %%
config='configuration_OA2023.yaml'
from pythetatools.config import load_config, inputs_dir, outputs_dir
load_config(f"{inputs_dir}/config_files/{config}")
from pythetatools.config import CONFIG

# %%
from analysis_scripts import save_and_plot_llh
from pythetatools.config_visualisation import *

from matplotlib import pyplot as plt

from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.style.use(t2k_style)

#%matplotlib ipympl
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set smear_factor

# %%
smear_factor = 3.3e-5

# %% [markdown]
# ## Set input and output paths

# %%
basedir = f'{inputs_dir}/{CONFIG.dir_ver}/MargTemplates'
outdir_path = f'{outputs_dir}/plots/{CONFIG.dir_ver}/dchi2'
outdir_files_path = f'{outputs_dir}/files/{CONFIG.dir_ver}/dchi2'

os.makedirs(outdir_path, exist_ok=True)
os.makedirs(outdir_files_path, exist_ok=True)

# %% [markdown]
# ## Plot dchi2 contours

# %%
smeared = True
mode = 0 
indir = f"{basedir}//MargTemplates_DataFit_dm2_100k_p-theta_mode_0"
prefix='DataFit'
#FC_filetemplate = f'{outputs_dir}/files/{dir_ver}/FC/'+'CriticalDchi2_{param_name_flattened}_{true_param}_truemh{mh}.npy'

save_and_plot_llh.plot_dchi2(indir, outdir_path, outdir_files_path, mode, prefix=prefix, smear_factor=smear_factor,
                             FC_filetemplate=None, smeared=smeared, save=True, plot_surface=False, save_root_file=True)
# Out:
# Tranformation will not be done as in your param_name there is not sin2213
