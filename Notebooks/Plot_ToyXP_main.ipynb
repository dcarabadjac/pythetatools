# %% [markdown]
# ## Import the necessary modules.
# Specify the version of the config file (it will set the OA-version dependent names, e.g. plot tag, output directory name etc)

# %%
config='configuration_OA2023.yaml'
from pythetatools.config import load_config, inputs_dir, outputs_dir
load_config(f"{inputs_dir}/config_files/{config}")
from pythetatools.config import CONFIG

# %%
#import the "header" script
from analysis_scripts.plot_toyxp_main import plot_data_vs_bestfit_nominalbinning, plot_data_vs_bestfit_2D_withproj, plot_data_vs_bestfit_1D

#import python libraries
import matplotlib.gridspec as gridspec
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import uproot

#set the style of the plots
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.style.use(t2k_style)


#necessary to autoreload the changes made in the .py scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set input and output paths

# %%
base_dir = f"{inputs_dir}/{CONFIG.dir_ver}/ToyXP"
outdir_path = f'{outputs_dir}/plots/{CONFIG.dir_ver}/ToyXp/'
os.makedirs(outdir_path, exist_ok=True)

# %% [markdown]
# # Specify the paths to AsimovBestFit and Data file

# %%
path_to_data = f"{base_dir}/Datafile_run11.root"
path_to_asimovbf = f"{base_dir}/ToyXP_AsimovBestFit_OA2023_postBanff.root"

# %% [markdown]
# # Plot samples how they are used in analysis

# %%
plot_data_vs_bestfit_nominalbinning(path_to_data, path_to_asimovbf, save=False)

# %% [markdown]
# # Plot 2D samples and projection to Erec and Angle

# %%
plot_data_vs_bestfit_2D_withproj(path_to_data, path_to_asimovbf, save=False)

# %% [markdown]
# # Plot 1D samples

# %%
plot_data_vs_bestfit_1D(path_to_data, path_to_asimovbf, save=False)
# Out:
# Trying to project 1D. The sample will not be modified.
# Trying to project 1D. The sample will not be modified.
