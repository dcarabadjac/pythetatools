# %%
config='configuration_OA2023.yaml'
from pythetatools.config import load_config, inputs_dir, outputs_dir
load_config(f"{inputs_dir}/config_files/{config}")
from pythetatools.config import CONFIG

# %%
from pythetatools.config_visualisation import *
from analysis_scripts import plot_pvalues

import os
from matplotlib import pyplot as plt

from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.style.use(t2k_style)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Set input and output directory

# %%
indir = f"{inputs_dir}/{CONFIG.dir_ver}/MargTemplates"
outdir_path = f'{outputs_dir}/plots/{CONFIG.dir_ver}/pvalues/'
os.makedirs(outdir_path, exist_ok=True)

# %% [markdown]
# ## Rate-only

# %%
rate_only = True
base_dir_toys_rateonly = f"{indir}/MargTemplates_OA2023_GoF_Thesis_mh_100k_rateonly_NH_mode_0"
base_dir_data_rateonly = f"{indir}/MargTemplates_DataFit_mh_400k_rateonly_mode_0"

# %%
plot_pvalues.plot_GOF_dchi2(base_dir_toys_rateonly, base_dir_data_rateonly, rate_only, outdir_path)
# Out:
# Number of entries in 'MargTemplate': 200000.
# No continous parameters are found. Hopefully you do p-values studies
# Grid sizes: [1] for parameters ['none']
# Number of entries in 'MargTemplate': 20.
# No continous parameters are found. Hopefully you do p-values studies
# Grid sizes: [1] for parameters ['none']

# %% [markdown]
# ## Rate+Shape

# %%
rate_only = False
base_dir_toys_rateshape = f"{indir}/MargTemplates_OA2023_GoF_Thesis_mh_100k_GOF_NH_mode_0"
base_dir_data_rateshape = f"{indir}/MargTemplates_DataFit_mh_400k_GOF_mode_0"

# %%
plot_pvalues.plot_GOF_dchi2(base_dir_toys_rateshape, base_dir_data_rateshape, rate_only, outdir_path)
# Out:
# Number of entries in 'MargTemplate': 200000.
# No continous parameters are found. Hopefully you do p-values studies
# Grid sizes: [1] for parameters ['none']
# Number of entries in 'MargTemplate': 200.
# No continous parameters are found. Hopefully you do p-values studies
# Grid sizes: [1] for parameters ['none']
